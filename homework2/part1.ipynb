# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Create a null vector of size 10
# Hint: np.zeros()
zero_vector = np.zeros(10)

# Create a vector with values ranging from 299 to 369
# Hint: np.arange()
range_vector = np.arange(299, 369)

# Make the 5th element of the existing vector to be 1
# Hint: np.array works quite similar to python list.
range_vector[4] = 1

# Reverse the existing vector (the 1st element becomes the last one)
# Hint: np.array works quite similar to python list.
reverse_vector = range_vector[::-1]

# Create a 3x3 matrix with values ranging from 0 to 8
# Hint: np.reshape()
matrix = np.arange(9).reshape(3, 3)

# Create a 3x3 matrix with a random float values
# Hint: np.random.rand()
matrix_float = np.random.rand(3, 3)

# Create a 3x3 matrix with a random int values
# Hint: np.random.randint()
matrix_int = np.random.randint(10, size=(3, 3))

# Find min, max and mean values of the existing matrix
min_matrix_int = np.min(matrix_int)
max_matrix_int = np.max(matrix_int)
mean_matrix_int = np.mean(matrix_int)

# Reshape the existing matrix into a vector
# Hint: np.reshape(), np.size()
vector_int = matrix_int.reshape(np.size(matrix_int))

# Add a border filled with 0's around the existing array
padded_arr = np.pad(vector_int, pad_width=1,
                    mode='constant', constant_values=0)

# Create 5x3 matrix and 3x2 matrix with a random int values, calculate dot-product of the created matrices
# Hint: np.dot()
matrix_a = np.random.randint(10, size=(5, 3))
matrix_b = np.random.randint(10, size=(3, 2))
dot_product = np.dot(matrix_a, matrix_b)


# Create a vector with a random float values, negate all elements which are between 3 and 8 (substitute original values with -1 * original value), in place.
# Hint: a[(condition 1) & (condition 2)]
vector = np.random.uniform(0, 10, 10)
vector[(vector > 3) & (vector < 8)] *= -1

# Create 2 vectors of the same chape, stack them vertically
# Hint: np.concatenate(), np.vstack()
vector_a = np.random.randint(10, size=10)
vector_b = np.random.randint(10, size=10)
vector_c = np.concatenate(
    (vector_a.reshape(1, -1), vector_b.reshape(1, -1)), axis=0)
vector_y = np.vstack((vector_a, vector_b))

# Take the existing vestors, stack them horizontally
# Hint: np.concatenate(), np.hstack()
vector_d = np.hstack((vector_a, vector_b))
vector_z = np.concatenate((vector_a, vector_b), axis=0)

# Flatten the resulted array
# Hint: np.flatten(), np.ravel(), np.reshape()
flaten_matrix = vector_y.flatten()
ravel_matrix = vector_y.ravel()

# Replace the maximum value by 0 in the existing vector
# Hint: np.argmax()
'''
    replace only first max value
'''
flaten_matrix[flaten_matrix.argmax()] = 0
result_matrix_1 = flaten_matrix

'''
    replace all max values
'''
max_value = flaten_matrix.max()
flaten_matrix[flaten_matrix == max_value] = 0
result_matrix_2 = flaten_matrix

# Create 2 random arrays A and B of the same shape, check if the created arrays are equal.
# Hint: np.allclose(), np.array_equal()
arr1 = np.array([1, 2, 3, 4, 5])
arr2 = np.array([1.001, 2.002, 3.003, 4.004, 5.005])
close_result = np.allclose(arr1, arr2, atol=0.01)
equal_result = np.array_equal(arr1, arr2)

# Create 2D array or take any existinng 2D array, swap any 2 rows of this 2D array.
# Hint: array[[]] = array[[]]
matrix3 = np.random.randint(10, size=(3, 3))
matrix3[0], matrix3[1] = matrix3[1], matrix3[0].copy()
